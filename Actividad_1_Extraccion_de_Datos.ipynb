# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeEduardoPL/Extraccion-de-Datos/blob/main/Actividad_1_Extraccion_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
dataf= pd.read_csv("CountryTable.csv")
dataf.head()
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %%
#Filtro por objeto
filtro1=dataf[dataf["continent"] == "Asia"]
filtro1
# Out:
#     code                  name continent                     region  \
# 1    AFG           Afghanistan      Asia  Southern and Central Asia
# 7    ARE  united Arab Emirates      Asia                Middle East
# 9    ARM               Armenia      Asia                Middle East
# 16   AZE            Azerbaijan      Asia                Middle East
# 21   BGD            Bangladesh      Asia  Southern and Central Asia
# 23   BHR               Bahrain      Asia                Middle East
# 32   BRN                Brunei      Asia             Southeast Asia
# 33   BTN                Bhutan      Asia  Southern and Central Asia
# 41   CHN                 China      Asia               Eastern Asia
# 54   CYP                Cyprus      Asia                Middle East
# 77   GEO               Georgia      Asia                Middle East
# 92   HKG             Hong Kong      Asia               Eastern Asia
# 98   IDN             Indonesia      Asia             Southeast Asia
# ...

# %%
#Filtrar por la columna continente y la variable como el continente asiatico.
filtro1.to_csv("Filtro1.csv")

# %%
#Filtro por filas
filtro2= dataf.iloc[10:20,: ]
filtro2
# Out:
#    code                         name      continent  \
# 10  ASM               American Samoa        Oceania
# 11  ATA                   Antarctica     Antarctica
# 12  ATF  French Southern territories     Antarctica
# 13  ATG          Antigua and Barbuda  North America
# 14  AuS                    Australia        Oceania
# 15  AuT                      Austria         Europe
# 16  AZE                   Azerbaijan           Asia
# 17  BDI                      Burundi         Africa
# 18  BEL                      Belgium         Europe
# 19  BEN                        Benin         Africa
#
#                        region  surface_area  independence_year  population  \
# 10                  Polynesia         199.0                NaN       68000
# 11                 Antarctica    13120000.0                NaN           0
# 12                 Antarctica        7780.0                NaN           0
# 13                  Caribbean         442.0             1981.0       68000
# ...

# %%
#filtro consecutivo desde la fila 11 hasta la fila 20
filtro2.to_csv("Filtro2.csv")

# %%
#Filtro por columnas
filtro3=dataf.iloc[ : , 2:4]
filtro3
# Out:
#          continent                     region
# 0    North America                  Caribbean
# 1             Asia  Southern and Central Asia
# 2           Africa             Central Africa
# 3    North America                  Caribbean
# 4           Europe            Southern Europe
# ..             ...                        ...
# 234           Asia                Middle East
# 235         Europe            Southern Europe
# 236         Africa            Southern Africa
# 237         Africa             Eastern Africa
# 238         Africa             Eastern Africa
#
# [239 rows x 2 columns]

# %%
#filtro consecutivo que muestra todas las filas pero con los datos desde la tercera columna hasta la cuarta
filtro3.to_csv("Filtro3.csv")

# %%
dataf= pd.read_csv("CountryTable.csv", index_col=2)#leer el dataframe con un indice
dataf
# Out:
#               code          name                     region  surface_area  \
# continent
# North America  ABW         Aruba                  Caribbean         193.0
# Asia           AFG   Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO        Angola             Central Africa     1246700.0
# North America  AIA      Anguilla                  Caribbean          96.0
# Europe         ALB       Albania            Southern Europe       28748.0
# ...            ...           ...                        ...           ...
# Asia           YEM         Yemen                Middle East      527968.0
# Europe         YuG    Yugoslavia            Southern Europe      102173.0
# Africa         ZAF  South Africa            Southern Africa     1221037.0
# Africa         ZMB        Zambia             Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#Filtro de filas vs columnas
filtro4=dataf.loc[["Asia","North America"], ["population"]]
filtro4
# Out:
#                population
# continent
# Asia             22720000
# Asia              2441000
# Asia              3520000
# Asia              7734000
# Asia            129155000
# ...                   ...
# North America     1295000
# North America   278357000
# North America      114000
# North America       21000
# North America       93000
#
# [88 rows x 1 columns]

# %%
#filtrar por filas con los datos de "Asia" y "North America" y con la columna de "population"
filtro4.to_csv("Filtro4.csv")

# %%
#Filtro por cabecera
filtro5=dataf.head(8)
filtro5
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# North America  AIA              Anguilla                  Caribbean
# Europe         ALB               Albania            Southern Europe
# Europe         AND               Andorra            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# Asia           ARE  united Arab Emirates                Middle East
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# North America         193.0                NaN      103000             78.4
# Asia               652090.0             1919.0    22720000             45.9
# Africa            1246700.0             1975.0    12878000             38.3
# ...

# %%
#mostrar los primeros 8 datos del dataframe
filtro5.to_csv("Filtro5.csv")

# %%
#Filtro por comparacion
filtro6=dataf[dataf["population"] > 2000000]
filtro6
# Out:
#               code                  name                     region  \
# continent
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# Europe         ALB               Albania            Southern Europe
# Asia           ARE  united Arab Emirates                Middle East
# South America  ARG             Argentina              South America
# ...            ...                   ...                        ...
# Asia           YEM                 Yemen                Middle East
# Europe         YuG            Yugoslavia            Southern Europe
# Africa         ZAF          South Africa            Southern Africa
# Africa         ZMB                Zambia             Eastern Africa
# Africa         ZWE              Zimbabwe             Eastern Africa
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %%
#filtra y muestra los datos que tengan una poblacion mayor a 2000000
filtro6.to_csv("Filtro6.csv")

# %%
#Filtro Y
filtro7=dataf[(dataf["population"] > 2000000) & (dataf["independence_year"] > 1919)]
filtro7
# Out:
#           code                  name                     region  surface_area  \
# continent
# Africa     AGO                Angola             Central Africa     1246700.0
# Asia       ARE  united Arab Emirates                Middle East       83600.0
# Asia       ARM               Armenia                Middle East       29800.0
# Asia       AZE            Azerbaijan                Middle East       86600.0
# Africa     BDI               Burundi             Eastern Africa       27834.0
# ...        ...                   ...                        ...           ...
# Europe     uKR               ukraine             Eastern Europe      603700.0
# Asia       uZB            uzbekistan  Southern and Central Asia      447400.0
# Asia       VNM               Vietnam             Southeast Asia      331689.0
# Africa     ZMB                Zambia             Eastern Africa      752618.0
# Africa     ZWE              Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#filtro que muestra los datos con una poblacion mayor a 2000000 y con un año de independencia mayor a 1919
filtro7.to_csv("Filtro7.csv")

# %%
#Filtro o
filtro8=dataf[(dataf["population"] > 2000000) | (dataf["independence_year"] < 1919)]
filtro8
# Out:
#           code                  name                     region  surface_area  \
# continent
# Asia       AFG           Afghanistan  Southern and Central Asia      652090.0
# Africa     AGO                Angola             Central Africa     1246700.0
# Europe     ALB               Albania            Southern Europe       28748.0
# Europe     AND               Andorra            Southern Europe         468.0
# Asia       ARE  united Arab Emirates                Middle East       83600.0
# ...        ...                   ...                        ...           ...
# Asia       YEM                 Yemen                Middle East      527968.0
# Europe     YuG            Yugoslavia            Southern Europe      102173.0
# Africa     ZAF          South Africa            Southern Africa     1221037.0
# Africa     ZMB                Zambia             Eastern Africa      752618.0
# Africa     ZWE              Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#filtro que muestra los datos con una poblacion mayor a 2000000 o con un año de independencia menor a 1919
filtro8.to_csv("Filtro8.csv")

# %%
#Filtro not
filtro9=dataf[~(dataf["population"] > 2000000) & ~(dataf["life_expectancy"] < 40 )]
filtro9
# Out:
#               code                     name           region  surface_area  \
# continent
# North America  ABW                    Aruba        Caribbean         193.0
# North America  AIA                 Anguilla        Caribbean          96.0
# Europe         AND                  Andorra  Southern Europe         468.0
# North America  ANT     Netherlands Antilles        Caribbean         800.0
# Oceania        ASM           American Samoa        Polynesia         199.0
# ...            ...                      ...              ...           ...
# North America  VGB  Virgin Islands, British        Caribbean         151.0
# North America  VIR     Virgin Islands, u.S.        Caribbean         347.0
# Oceania        VuT                  Vanuatu        Melanesia       12189.0
# Oceania        WLF        Wallis and Futuna        Polynesia         200.0
# Oceania        WSM                    Samoa        Polynesia        2831.0
#
# ...

# %%
#filtro que muestra los datos que no tengan una poblacion mayor a 2000000 y que su espectativa de vida no sea menor a 40
filtro9.to_csv("Filtro9.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro1.csv")
files.download("Filtro2.csv")
files.download("Filtro3.csv")
files.download("Filtro4.csv")
files.download("Filtro5.csv")
files.download("Filtro6.csv")
files.download("Filtro7.csv")
files.download("Filtro8.csv")
files.download("Filtro9.csv")
